# %% [markdown]
# ### PANDAS

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
# df1 = pd.DataFrame([10,20,30])
# df1
df2 = pd.DataFrame(["Angel" , "sneha","riya"],columns = ["names of students"])
print(df2)
print(type(df2))
# Out:
#   names of students
# 0             Angel
# 1             sneha
# 2              riya
# <class 'pandas.core.frame.DataFrame'>

# %%
data = {"name" : ["Angel" , "Alka" , "Sneha" , "Riya" , "Maya" ],
        "age" : [18,19,18,21,33],
        "marks" : [90,93,99,99,67]
       }
data
# Out:
# {'name': ['Angel', 'Alka', 'Sneha', 'Riya', 'Maya'],
#  'age': [18, 19, 18, 21, 33],
#  'marks': [90, 93, 99, 99, 67]}

# %%
df = pd.DataFrame(data)
print(df)
print(type(df))
df.head(2)
# Out:
#     name  age  marks
# 0  Angel   18     90
# 1   Alka   19     93
# 2  Sneha   18     99
# 3   Riya   21     99
# 4   Maya   33     67
# <class 'pandas.core.frame.DataFrame'>
#     name  age  marks
# 0  Angel   18     90
# 1   Alka   19     93

# %%
df.tail(2)
# Out:
#    name  age  marks
# 3  Riya   21     99
# 4  Maya   33     67

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['name', 'age', 'marks'], dtype='object')

# %%
df.rename (columns = {"age" : "student age" } ,inplace = True)
df
# Out:
#     name  student age  marks
# 0  Angel           18     90
# 1   Alka           19     93
# 2  Sneha           18     99
# 3   Riya           21     99
# 4   Maya           33     67

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          5 non-null      object
#  1   student age   5 non-null      int64
#  2   marks         5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
df.describe()
# Out:
#        student age       marks
# count      5.000000   5.000000
# mean      21.800000  89.600000
# std        6.379655  13.221195
# min       18.000000  67.000000
# 25%       18.000000  90.000000
# 50%       19.000000  93.000000
# 75%       21.000000  99.000000
# max       33.000000  99.000000

# %%
df.to_csv("Test_data.csv" , index = False)
load_df = pd.read_csv("Test_data.csv")
load_df
# Out:
#     name  student age   marks
# 0  Angel            18     90
# 1   Alka            19     93
# 2  Sneha            18     99
# 3   Riya            21     99
# 4   Maya            33     67

# %%
pd.read_csv ("Test_data.csv")
# Out:
#     name  student age   marks
# 0  Angel            18     90
# 1   Alka            19     93
# 2  Sneha            18     99
# 3   Riya            21     99
# 4   Maya            33     67

# %%
df.loc[df.name == 'Angel']
# Out:
#     name  student age   marks
# 0  Angel            18     90

# %%
df.loc[(df.name=='Angel') & (df.marks == 90)]
# Out:
#     name  student age   marks
# 0  Angel            18     90

# %%
df.iloc[0:2]
# Out:
#     name  student age   marks
# 0  Angel            18     90
# 1   Alka            19     93

# %%
df.loc[0:2]
# Out:
#     name  student age   marks
# 0  Angel            18     90
# 1   Alka            19     93
# 2  Sneha            18     99

# %%
df['student age'] >=19
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'student age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 df['student age'] >=19
#
# ...

# %%
df.where(df["age"]>18)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df.where(df["age"]>18)
#
# ...

# %%
df.where(df['age']>18 , other = "pagal")
# Out:
#     name    age  marks
# 0  pagal  pagal  pagal
# 1   Alka     19     93
# 2  pagal  pagal  pagal
# 3   Riya     21     99
# 4   Maya     33     67

# %%
df['team'] = ['go3d' , 'go3d' , 'techbyte' , 'techbyte' , 'go3d']
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df['team'] = ['go3d' , 'go3d' , 'techbyte' , 'techbyte' , 'go3d']
#       2 print(df)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4322, in DataFrame.__setitem__(self, key, value)
#    4319     self._setitem_array([key], value)
#    4320 else:
#    4321     # set column
# -> 4322     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4535, in DataFrame._set_item(self, key, value)
#    4525 def _set_item(self, key, value) -> None:
#    4526     """
#    4527     Add series to DataFrame in specified column.
#    4528
#    (...)   4533     ensure homogeneity.
#    4534     """
# -> 4535     value, refs = self._sanitize_column(value)
#    4537     if (
#    4538         key in self.columns
#    4539         and value.ndim == 1
# ...

# %%
df['percent' ] = (df["marks" ] /200 ) *100

# %%
df
# Out:
#     name  age  marks      team  grades  percent
# 0  Angel   18     90      go3d    45.0     45.0
# 1   Alka   19     93      go3d    46.5     46.5
# 2  Sneha   18     99  techbyte    49.5     49.5
# 3   Riya   21     99  techbyte    49.5     49.5
# 4   Maya   33     67      go3d    33.5     33.5

# %%
df.loc[0,"name"] = "Annie"
df
# Out:
#     name  age  marks      team  grades  percent
# 0  Annie   18     90      go3d    45.0     45.0
# 1   Alka   19     93      go3d    46.5     46.5
# 2  Sneha   18     99  techbyte    49.5     49.5
# 3   Riya   21     99  techbyte    49.5     49.5
# 4   Maya   33     67      go3d    33.5     33.5

# %%
df.loc[df.name == "Sneha" , "marks"] = 80
df
# Out:
#     name  age  marks      team  grades  percent
# 0  Annie   18     90      go3d    45.0     45.0
# 1   Alka   19     93      go3d    46.5     46.5
# 2  Sneha   18     80  techbyte    49.5     49.5
# 3   Riya   21     99  techbyte    49.5     49.5
# 4   Maya   33     67      go3d    33.5     33.5

# %%
df.drop()

# %%
df = df.drop(df[df.name == "Maya" ].index)
df
# Out:
#     name  age  marks      team  grades  percent
# 0  Annie   18     90      go3d    45.0     45.0
# 1   Alka   19     93      go3d    46.5     46.5
# 2  Sneha   18     80  techbyte    49.5     49.5
# 3   Riya   21     99  techbyte    49.5     49.5

# %%
df.drop(1,axis=0)
df
# Out:
#     name  age  marks      team  grades  percent
# 0  Annie   18     90      go3d    45.0     45.0
# 1   Alka   19     93      go3d    46.5     46.5
# 2  Sneha   18     80  techbyte    49.5     49.5
# 3   Riya   21     99  techbyte    49.5     49.5

# %%
df.drop('team',axis=1,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df.drop('team',axis=1,inplace=True)
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df.sort_values('student age',ascending = True , inplace = True)
df
# Out:
#     name  student age  marks
# 0  Angel           18     90
# 2  Sneha           18     99
# 1   Alka           19     93
# 3   Riya           21     99
# 4   Maya           33     67

# %%
df
# Out:
#     name  student age  marks
# 0  Angel           18     90
# 1   Alka           19     93
# 2  Sneha           18     99
# 3   Riya           21     99
# 4   Maya           33     67

# %%
df['doj']=['20-12-2007','30-12-2007','01-01-2008','23-04-2008','09-09-2009']
df
# Out:
#     name  student age  marks         doj
# 0  Angel           18     90  20-12-2007
# 2  Sneha           18     99  30-12-2007
# 1   Alka           19     93  01-01-2008
# 3   Riya           21     99  23-04-2008
# 4   Maya           33     67  09-09-2009

# %%
df["doj"] =pd.to_datetime(df["doj"])
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_15796\2147076749.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["doj"] =pd.to_datetime(df["doj"])

# %%
df["doj"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df["doj"].dt.year
# Out:
# 0    2007
# 2    2007
# 1    2008
# 3    2008
# 4    2009
# Name: doj, dtype: int32

# %%
df["doj"].dt.month
# Out:
# 0    12
# 2    12
# 1     1
# 3     4
# 4     9
# Name: doj, dtype: int32

# %%
df["doj"].dt.day_name()
# Out:
# 0     Thursday
# 2       Sunday
# 1      Tuesday
# 3    Wednesday
# 4    Wednesday
# Name: doj, dtype: object

# %%
df["doj"].dt.date
# Out:
# 0    2007-12-20
# 2    2007-12-30
# 1    2008-01-01
# 3    2008-04-23
# 4    2009-09-09
# Name: doj, dtype: object

# %%
df.isnull()
# Out:
#     name  student age  marks    doj
# 0  False        False  False  False
# 2  False        False  False  False
# 1  False        False  False  False
# 3  False        False  False  False
# 4  False        False  False  False

# %%
import numpy as np 
df.loc[df.name =="Riya" , "marks"] = np.nan

# %%
df
# Out:
#     name  student age  marks        doj
# 0  Angel           18   90.0 2007-12-20
# 2  Sneha           18   99.0 2007-12-30
# 1   Alka           19   93.0 2008-01-01
# 3   Riya           21    NaN 2008-04-23
# 4   Maya           33   67.0 2009-09-09

# %%
df.isnull()
# Out:
#     name  student age  marks    doj
# 0  False        False  False  False
# 2  False        False  False  False
# 1  False        False  False  False
# 3  False        False   True  False
# 4  False        False  False  False

# %%
df.isnull().sum()
# Out:
# name           0
# student age    0
# marks          1
# doj            0
# dtype: int64

# %%
df.fillna(0)
# Out:
#     name  student age  marks        doj
# 0  Angel           18   90.0 2007-12-20
# 2  Sneha           18   99.0 2007-12-30
# 1   Alka           19   93.0 2008-01-01
# 3   Riya           21    0.0 2008-04-23
# 4   Maya           33   67.0 2009-09-09

# %%
df.loc[df.name=="Riya" , "marks" ] = 78
df
# Out:
#     name  student age  marks        doj
# 0  Angel           18   90.0 2007-12-20
# 2  Sneha           18   99.0 2007-12-30
# 1   Alka           19   93.0 2008-01-01
# 3   Riya           21   78.0 2008-04-23
# 4   Maya           33   67.0 2009-09-09

# %%
df1 = pd.DataFrame({'id':[1,2,3] , 'name': ['A' , 'B' , 'C' ]})

# %%
DF2 = pd.DataFrame({'id' : [1,2,3] , 'name' : ['d' , 'e' , 'f' ]})

# %%
pd.concat([df1,DF2] , axis = 1)
# Out:
#    id name  id name
# 0   1    A   1    d
# 1   2    B   2    e
# 2   3    C   3    f

# %%
df3 = pd.concat([df1,DF2] , axis = 0)
df3
# Out:
#    id name
# 0   1    A
# 1   2    B
# 2   3    C
# 0   1    d
# 1   2    e
# 2   3    f

# %%
pd.merge(df1, DF2, how = 'inner')
# Out:
# Empty DataFrame
# Columns: [id, name]
# Index: []

# %%
df
# Out:
#     name  student age  marks        doj
# 0  Angel           18   90.0 2007-12-20
# 2  Sneha           18   99.0 2007-12-30
# 1   Alka           19   93.0 2008-01-01
# 3   Riya           21   78.0 2008-04-23
# 4   Maya           33   67.0 2009-09-09

# %%
df.query("student age == 18 and marks >= 95" )
# Out:
# Traceback (most recent call last):
#
#   File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[159], line 1
#     df.query("student age == 18 and marks >= 95" )
#
#   File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4834 in query
#     res = self.eval(expr, **kwargs)
#
#   File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4960 in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File ~\anaconda3\Lib\site-packages\pandas\core\computation\eval.py:339 in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:809 in __init__
#     self.terms = self.parse()
#
#   File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:828 in parse
#     return self._visitor.visit(self.expr)
#
#   File ~\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:409 in visit
# ...
