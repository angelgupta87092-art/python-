# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
y = [10,20,305,44,59]
x = [1,2,3,4,5]
plt.plot(x,y)
plt.show()

# %%
plt.figure(figsize = (4,4))
plt.plot(x,y , color = 'green' , marker = '+' , linestyle = '-.' , linewidth = 2 , markersize = 10)
plt.title("title")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
x = [1995 , 2000, 2005 , 2010 ]
y = [10,20,34,45]
plt.plot(x,y)
plt.title('kuch v ' )
plt.xlabel('years')
plt.ylabel("amount in rs crore")

plt.figure(figsize = (2 ,9))
plt.show()

# %%
x = [1,2,3,4,5]
y1 = [10,20,30,40,50]
y2 = [20,30 , 35 , 45 , 55] 

plt.plot(x , y1 , label = 'sales 2024')
plt.plot(x , y2 , label = 'sales 2025' )

plt.title('yearly salary')
plt.xlabel('months')
plt.ylabel('sales')

plt.legend()
plt.show()

# %%
x = ["maths " , 'eng' , 'science' , 'hindi' , 'sst' ]
y = [89, 90 , 78 , 99 , 98] 

plt.bar(x,y , width = 0.5)

plt.title("marks of student")
plt.xlabel("subjects")
plt.ylabel("marks")

plt.show()

# %%
import random 
data = random.randint

# %%
marks = [10,20,10,40,33,20,35,54,22,35]
plt.hist(marks , bins = 4 )
plt.title("histogram")
plt.xlabel("marks")
plt.ylabel("freq")
plt.show()

# %%
category = [ "A" , "B" , "C" , "D" , "E" , "F" ]
sales = [10,20,30,43,34 , 78]

plt.pie(sales , labels = category , autopct = '%1.2d%%' , startangle = 180)
plt.title("pie chart ")
plt.show()

# %%
y1 = [10,20,30,40 ,45]
y2 = [20,40,78,34 ,90]
plt.scatter(y1,y2)
plt.title("SCatter plot")
plt.show()

# %%
category = [ "A" , "B" , "C" , "D" , "E" , "F" ]
sales = [10,20,30,43,34 , 78]

plt.subplot(1,2,1)
plt.bar(category, sales)
plt.title('bar graph')




y1 = [10,20,30,40 ,45]
y2 = [20,40,78,34 ,90]

plt.subplot(1,2,2)
plt.scatter(y1,y2)
plt.title("SCatter plot")

plt.show()


category = [ "A" , "B" , "C" , "D" , "E" , "F" ]
sales = [10,20,30,43,34 , 78]
plt.subplot(1,2,2)
plt.pie(sales , labels = category , autopct = '%1.2d%%' , startangle = 180)
plt.title("pie chart ")


plt.show()

# %%
#matplotlib with panda 
import pandas as pd 

data = {
    "months" : ["jan" , "feb" , "march" , "apr" ],
    "sales" : [12000, 30000, 50000, 50000]
}
df = pd.DataFrame(data)
df
# Out:
#   months  sales
# 0    jan  12000
# 1    feb  30000
# 2  march  50000
# 3    apr  50000

# %%
plt.bar(df["months"] ,df["sales"])
plt.title("matplotlib with panda")
plt.xlabel("months")
plt.ylabel("sales")
plt.savefig("img.png")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="dark")

# Simulate data from a bivariate Gaussian
n = 10000
mean = [0, 0]
cov = [(2, .4), (.4, .2)]
rng = np.random.RandomState(0)
x, y = rng.multivariate_normal(mean, cov, n).T

# Draw a combo histogram and scatterplot with density contours
f, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(x=x, y=y, s=5, color=".15")
sns.histplot(x=x, y=y, bins=50, pthresh=.1, cmap="mako")
sns.kdeplot(x=x, y=y, levels=5, color="w", linewidths=1)
# Out:
# <Axes: >
